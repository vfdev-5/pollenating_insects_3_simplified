# %% [markdown]
# Check before a submit

# %%
# !pip install imbalanced-learn

# %%
# !cd ../../ramp-workflow/ && python setup.py install
# Out:
# /usr/local/lib/python2.7/dist-packages/setuptools/dist.py:351: UserWarning: Normalizing '0.1.dev' to '0.1.dev0'
#   normalized_version,
# running install
# running bdist_egg
# running egg_info
# writing requirements to ramp_workflow.egg-info/requires.txt
# writing ramp_workflow.egg-info/PKG-INFO
# writing top-level names to ramp_workflow.egg-info/top_level.txt
# writing dependency_links to ramp_workflow.egg-info/dependency_links.txt
# writing entry points to ramp_workflow.egg-info/entry_points.txt
# reading manifest file 'ramp_workflow.egg-info/SOURCES.txt'
# writing manifest file 'ramp_workflow.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying rampwf/utils/testing.py -> build/lib.linux-x86_64-2.7/rampwf/utils
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/rampwf
# creating build/bdist.linux-x86_64/egg/rampwf/workflows
# ...

# %%
# !pip install git+git://github.com/aleju/imgaug/
# !pip install git+git://github.com/farizrahman4u/keras-contrib
# Out:
# ...
#   Cloning git://github.com/aleju/imgaug/ to /tmp/pip-hW9ZAD-build
# ...
#   Running setup.py install for imgaug ... done
# ...
#   Cloning git://github.com/farizrahman4u/keras-contrib to /tmp/pip-hHfFNG-build
# ...
#   Running setup.py install for keras-contrib ... done
# ...

# %%
# !pip install --upgrade git+https://github.com/fchollet/keras/
# !pip install Keras==2.0.6
# Out:
# ...
#   Cloning https://github.com/fchollet/keras/ to /tmp/pip-1Y7hFc-build
# Requirement already up-to-date: numpy>=1.9.1 in /usr/local/lib/python2.7/dist-packages (from Keras==2.0.8)
# Requirement already up-to-date: scipy>=0.14 in /usr/local/lib/python2.7/dist-packages (from Keras==2.0.8)
# Requirement already up-to-date: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from Keras==2.0.8)
# Requirement already up-to-date: pyyaml in /usr/local/lib/python2.7/dist-packages (from Keras==2.0.8)
# ...
#   Found existing installation: Keras 2.0.6
#     Uninstalling Keras-2.0.6:
#       Successfully uninstalled Keras-2.0.6
#   Running setup.py install for Keras ... done
# ...

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''

submission='pytorch_DenseNet161_finetunning_imbalanced'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''

submission='pytorch_DenseNet161_finetunning_imbalanced2'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''

submission='pytorch_DenseNet161_finetunning_imbalanced2'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
# os.environ['LOCAL_TESTING'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_DenseNet161_finetunning_imbalanced2_20171103_1203'

submission='pytorch_DenseNet161_finetunning_imbalanced2'
# !ramp_test_submission --submission {submission}
# Out:
# Testing Pollenating insect classification (403 classes), simplified workflow
# Reading train and test files from ./data ...
# Reading cv ...
# Training ./submissions/pytorch_DenseNet161_finetunning_imbalanced2 ...
# HAS_GPU: True
# ('features.conv0.weight', (96L, 3L, 7L, 7L))
# ('features.norm0.weight', (96L,))
# ('features.norm0.bias', (96L,))
# ('features.denseblock1.denselayer1.norm.1.weight', (96L,))
# ('features.denseblock1.denselayer1.norm.1.bias', (96L,))
# ('features.denseblock1.denselayer1.conv.1.weight', (192L, 96L, 1L, 1L))
# ('features.denseblock1.denselayer1.norm.2.weight', (192L,))
# ('features.denseblock1.denselayer1.norm.2.bias', (192L,))
# ('features.denseblock1.denselayer1.conv.2.weight', (48L, 192L, 3L, 3L))
# ('features.denseblock1.denselayer2.norm.1.weight', (144L,))
# ('features.denseblock1.denselayer2.norm.1.bias', (144L,))
# ('features.denseblock1.denselayer2.conv.1.weight', (192L, 144L, 1L, 1L))
# ('features.denseblock1.denselayer2.norm.2.weight', (192L,))
# ...

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''

submission='pytorch_DenseNet161_finetunning_imbalanced_299'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_DenseNet169_finetunning_imbalanced2a_20171025_2116'

submission='keras_DenseNet169_finetunning_imbalanced'
# !ramp_test_submission --submission {submission} 
# > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
# Out:
# Testing Pollenating insect classification (403 classes), simplified workflow
# Reading train and test files from ./data ...
# Reading cv ...
# Training ./submissions/keras_DenseNet169_finetunning_imbalanced ...
# Traceback (most recent call last):
#   File "/usr/local/bin/ramp_test_submission", line 11, in <module>
#     load_entry_point('ramp-workflow==0.1.dev0', 'console_scripts', 'ramp_test_submission')()
#   File "/usr/local/lib/python2.7/dist-packages/ramp_workflow-0.1.dev0-py2.7.egg/rampwf/utils/command_line.py", line 67, in ramp_test_submission
#     is_pickle=is_pickle)
#   File "/usr/local/lib/python2.7/dist-packages/ramp_workflow-0.1.dev0-py2.7.egg/rampwf/utils/testing.py", line 117, in assert_submission
#     module_path, X_train, y_train, train_is=train_is)
#   File "/usr/local/lib/python2.7/dist-packages/ramp_workflow-0.1.dev0-py2.7.egg/rampwf/workflows/simplified_image_classifier.py", line 57, in train_submission
# ...

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
os.environ['LOAD_BEST_MODEL'] = ''
os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_keras_ensembling_0_20171102_1650'

submission='keras_ensembling_0'
# !ramp_test_submission --submission {submission} 
# > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
# Out:
# Testing Pollenating insect classification (403 classes), simplified workflow
# Reading train and test files from ./data ...
# Reading cv ...
# Training ./submissions/keras_ensembling_0 ...
# Using TensorFlow backend.
# 2017-11-02 16:49:54.247846: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-02 16:49:54.247870: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-11-02 16:49:54.247882: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
os.environ['LOAD_BEST_MODEL'] = ''
os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_keras_ensembling_0_20171102_1650'

submission='keras_ensembling_0'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
# Out:
# ^C

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_DenseNet169_finetunning_imbalanced2a_20171025_2116'

submission='keras_Xception_finetunning_imbalanced'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_DenseNet169_finetunning_imbalanced2a_20171025_2116'

submission='keras_Xception_finetunning_imbalanced2'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
# Out:
# ^C

# %%
# import os
# from datetime import datetime
# now = datetime.now()
# os.environ['LOCAL_TESTING'] = ''
# # os.environ['LOAD_BEST_MODEL'] = ''
# # os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_keras_Xception_finetunning_imbalanced_20171102_2317'

# submission='keras_Xception_finetunning_imbalanced'
# !ramp_test_submission --submission {submission}

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_keras_ensembling_1_20171104_2034'

submission='keras_ensembling_1'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
# Out:
# ^C

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_SqueezeNet_finetunning_imbalanced_299'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_SqueezeNet_finetunning_balanced_299'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_SqueezeNet_finetunning_balanced2_299'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_SqueezeNet_finetunning_balanced3_299'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_chan_15Oct0z'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1

# %%
import os
from datetime import datetime
now = datetime.now()
os.environ['LOCAL_TESTING'] = ''
# os.environ['CHECK_MODE'] = ''
# os.environ['LOAD_BEST_MODEL'] = ''
# os.environ['LOGS_PATH'] = '/home/working_directory/ml/ramp-kits/pollenating_insects_3_simplified/logs_pytorch_SqueezeNet_finetunning_imbalanced_299_20171106_1851'

submission='pytorch_chan_15Oct0z_2'
# !ramp_test_submission --submission {submission} > submissions/{submission}/log_{now.strftime("%Y-%m-%d-%H-%M")} 2>&1
